# %%
from turtle import *
import turtle
import importlib; importlib.reload(turtle)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
t = Terrarium()
t1 = Turtle(t)
t1.forward(100)
t1.left(90)
t1.forward(100)
t.rescale()

# %%
t = Terrarium(5)
t1 = Turtle(t)
n = 50
for i in range(n):
    t1.forward(n-i)
    t1.left(90)
t.rescale()

# %%
t = Terrarium(5)
t1 = Turtle(t)
n = 50
for i in range(n):
    t1.forward(n-i)
    t1.left(90-i)
t.rescale()

# %%
with Terrarium(5, animate=True) as t:
    t1 = Turtle(t)
    n = 50
    for i in range(n):
        t1.forward(n-i)
        t1.left(90)
# Out:
# <video width="360" height="360" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
# dynamic dispatch
def square(turtle, length):
    for i in range(4):
        turtle.forward(length)
        turtle.left(90)
        
Turtle.square = square

with Terrarium() as terra:
    t1 = Turtle(terra)
    t1.square(10)

# %%
with Terrarium(5) as terra:
    t1 = Turtle(terra)
    for i in range(36):
        t1.left(10)
        t1.square(10)

# %%
with Terrarium(size =5, animate = True) as terra:
    t1 = Turtle(terra)
    for i in range(36):
        t1.left(10)
        t1.square(10)
# Out:
# <video width="360" height="360" controls autoplay>
#   <source type="video/mp4" src="...
